# %% [markdown]
# <a href="https://colab.research.google.com/github/roiskhoiron/.github/blob/master/Jago_Sentiment_Analysist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
